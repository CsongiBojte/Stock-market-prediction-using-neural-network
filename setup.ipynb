# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction')

import os
ROOT_PATH = '/content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction'
BASE_PATH = os.path.join(ROOT_PATH, 'models/lstm')

setup_file = os.path.join(ROOT_PATH, 'setup.py')
with open(setup_file, 'w') as f:
   f.write("""from setuptools import setup, find_packages

setup(
   name="stock_prediction",
   version="0.1",
   packages=find_packages(),
   install_requires=open('requirements.txt').read().splitlines()
)""")

# Install using requirements
# !pip install -r "{ROOT_PATH}/requirements.txt"
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (0.2.52)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 3)) (0.3.14b0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (5.24.1)
# Requirement already satisfied: notebook>=5.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (6.5.5)
# Requirement already satisfied: ipywidgets>=7.5 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (7.7.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (3.6.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (2.18.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 12)) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (1.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (3.1.5)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (6.4.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (5.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (3.0.13)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/dist-packages (from bokeh->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (2025.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.14.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 13)) (2025.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (0.45.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (21.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.24.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.2.13)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (1.3.1)
