# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction')

import os
ROOT_PATH = '/content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction'
BASE_PATH = os.path.join(ROOT_PATH, 'models/lstm')

# Install using requirements
# %pip install -r "{ROOT_PATH}/requirements.txt"
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (0.2.55)
# Collecting pandas_ta (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 3))
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting selenium (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4))
#   Downloading selenium-4.30.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (5.24.1)
# Requirement already satisfied: notebook>=5.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (6.5.7)
# Requirement already satisfied: ipywidgets>=7.5 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (7.7.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (3.6.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (2.18.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 12)) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 14)) (2.2.2)
# Collecting import-ipynb (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 15))
#   Downloading import_ipynb-0.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting ta (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 16))
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mlflow (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading mlflow-2.21.2-py3-none-any.whl.metadata (30 kB)
# Collecting pyngrok (from -r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 18))
#   Downloading pyngrok-7.2.3-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (4.13.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (2.3.0)
# Collecting trio~=0.17 (from selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4))
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4))
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 7)) (9.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (3.0.13)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/dist-packages (from bokeh->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 10)) (2025.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (5.29.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 12)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 12)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 12)) (0.14.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 14)) (2025.1)
# Collecting mlflow-skinny==2.21.2 (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading mlflow_skinny-2.21.2-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (3.1.0)
# Collecting alembic!=1.10.0,<2 (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (3.7)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (18.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (2.0.39)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading databricks_sdk-0.49.0-py3-none-any.whl.metadata (38 kB)
# Collecting fastapi<1 (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (1.31.1)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (2.10.6)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (0.5.3)
# Collecting uvicorn<1 (from mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (1.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.45.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (2.6)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (1.9.0)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (5.9.5)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (4.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 2)) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (3.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4))
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4))
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 4)) (1.7.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (21.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (2.38.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17))
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (0.23.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (0.52b1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 9)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (2.27.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<1->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (0.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (4.9)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=5.3->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow->-r /content/drive/MyDrive/Colab Notebooks/Stock_Market_Prediction/requirements.txt (line 17)) (0.6.1)
# Downloading selenium-4.30.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 64.4 MB/s eta 0:00:00
# Downloading import_ipynb-0.2-py3-none-any.whl (4.0 kB)
# Downloading mlflow-2.21.2-py3-none-any.whl (28.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 63.5 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.21.2-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 22.9 MB/s eta 0:00:00
# Downloading pyngrok-7.2.3-py3-none-any.whl (23 kB)
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 17.3 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 8.4 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 9.6 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.8 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 31.3 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading databricks_sdk-0.49.0-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.0/684.0 kB 37.9 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 6.8 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 14.0 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.9 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.7 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.1 MB/s eta 0:00:00
# Building wheels for collected packages: pandas_ta, ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=eb34482e5e55b2f1a5bb9fbf8cb4db9c92b8f2a00dc0a311708195d3f571df63
#   Stored in directory: /root/.cache/pip/wheels/7f/33/8b/50b245c5c65433cd8f5cb24ac15d97e5a3db2d41a8b6ae957d
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=29c91559d7a101b41c053e989fd2724dfa458d7154bcfb5627c8cec9b8cefc2b
#   Stored in directory: /root/.cache/pip/wheels/a1/d7/29/7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built pandas_ta ta
# Installing collected packages: wsproto, uvicorn, pyngrok, outcome, jedi, gunicorn, graphql-core, trio, starlette, graphql-relay, docker, alembic, trio-websocket, ta, pandas_ta, graphene, fastapi, databricks-sdk, selenium, mlflow-skinny, import-ipynb, mlflow
# Successfully installed alembic-1.15.2 databricks-sdk-0.49.0 docker-7.1.0 fastapi-0.115.12 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 import-ipynb-0.2 jedi-0.19.2 mlflow-2.21.2 mlflow-skinny-2.21.2 outcome-1.3.0.post0 pandas_ta-0.3.14b0 pyngrok-7.2.3 selenium-4.30.0 starlette-0.46.1 ta-0.11.0 trio-0.29.0 trio-websocket-0.12.2 uvicorn-0.34.0 wsproto-1.2.0
